# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('working_df.csv')

# %%
df
# Out:
#       Unnamed: 0  Stock_Market  Deposit_Interest_Rate  Interest_Rate  \
# 0     2000-02-01  5.200000e-03                  17.32          26.99
# 1     2000-03-01  5.900000e-03                  14.47          26.12
# 2     2000-05-01  5.500000e-03                  16.10          26.65
# 3     2000-06-01  6.900000e-03                  19.68          22.89
# 4     2000-08-01  6.700000e-03                  15.73          25.54
# ...          ...           ...                    ...            ...
# 4160  2021-11-11  6.078510e+11                  36.00          56.86
# 4161  2021-11-12  6.014640e+11                  36.00          56.86
# 4162  2021-11-15  5.973510e+11                  36.00          56.86
# 4163  2021-11-16  5.962450e+11                  36.00          56.86
# 4164  2021-11-17  5.968420e+11                  36.00          56.86
#
#       Money_Supply_M3  Central_Bank_Balance_Sheet  Crude_Oil_Production  \
# ...

# %%
df.sort_values('DateTime', inplace=True)

# %%
df.set_index('DateTime')

# %%
df['Foreign_Exchange_Reserve'].dropna()

# %%
df_gov_budget.tail(15)

# %%
plt.plot(df_gov_expenditure['Value'])

# %%
df_gov_expenditure

# %%
df_currency = pd.read_csv('historical_country_Venezuela_indicator_Currency.csv')

# %%
plt.plot(df_currency['Value'])

# %%
df_gov_debt['Value'].isnull()

# %%
plt.plot(df_gov_debt['DateTime'], df_gov_debt['Value'])

# %%
df_currency_frank = pd.read_csv('merge.csv')

df_currency_frank

# %%
df_currency_frank['Dolartoday'].nunique()

# %%
df_currency_frank['Dolartoday'].dropna()

# %%
plt.plot(df_currency_frank['Dolartoday'])

# %%
df_origin
