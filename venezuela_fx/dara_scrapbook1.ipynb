# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_pacf, plot_acf
from pmdarima.arima.utils import ndiffs
from statsmodels.tsa.arima.model import ARIMA
import pmdarima as pm
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
df = pd.read_csv('data_csv/working_df.csv')

# %%
df
# Out:
#       Unnamed: 0  Stock_Market  Deposit_Interest_Rate  Interest_Rate  \
# 0     2007-01-01  5.300000e-02                  10.53          18.93
# 1     2007-01-02  5.300000e-02                  10.12          18.93
# 2     2007-01-03  5.360000e-02                  10.07          18.24
# 3     2007-01-04  5.560000e-02                  10.01          14.77
# 4     2007-01-05  5.940000e-02                  10.03          17.43
# ...          ...           ...                    ...            ...
# 5432  2021-11-15  5.973510e+09                  36.00          56.86
# 5433  2021-11-16  5.962450e+09                  36.00          56.86
# 5434  2021-11-17  5.968420e+09                  36.00          56.86
# 5435  2021-11-18  5.998970e+09                  36.00          56.86
# 5436  2021-11-19  6.043920e+09                  36.00          56.86
#
#       Money_Supply_M3  Central_Bank_Balance_Sheet  Crude_Oil_Production  \
# ...

# %%
np.log(df['Dolartoday'])
# Out:
# 0      -10.292096
# 1      -10.292096
# 2      -10.288100
# 3      -10.278181
# 4      -10.263740
#           ...
# 5432    15.343738
# 5433    15.360943
# 5434    15.388284
# 5435    15.388284
# 5436    15.388284
# Name: Dolartoday, Length: 5437, dtype: float64

# %%
model = ARIMA(np.log(df['Dolartoday']), order=(30, 0, 0)).fit()
# Out:
# /Users/daraalizadeh/.pyenv/versions/3.8.12/envs/venezuela_fx/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/daraalizadeh/.pyenv/versions/3.8.12/envs/venezuela_fx/lib/python3.8/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:             Dolartoday   No. Observations:                 5437
# Model:                ARIMA(30, 0, 0)   Log Likelihood                8353.396
# Date:                Mon, 29 Nov 2021   AIC                         -16642.793
# Time:                        15:55:42   BIC                         -16431.561
# Sample:                             0   HQIC                        -16569.073
#                                - 5437
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.1003      0.220    -14.074      0.000      -3.532      -2.669
# ar.L1         -0.0271      0.010     -2.848      0.004      -0.046      -0.008
# ar.L2          1.4667      0.015     97.104      0.000       1.437       1.496
# ...

# %%
df.dtypes
# Out:
# date                           object
# Stock_Market                  float64
# Deposit_Interest_Rate         float64
# Interest_Rate                 float64
# Money_Supply_M3               float64
# Central_Bank_Balance_Sheet    float64
# Crude_Oil_Production          float64
# Crude_Oil_Rig                 float64
# Money_Supply_M0               float64
# Foreign_Exchange_Reserve      float64
# External_Debt                 float64
# Inflation_Rate                float64
# Money_Supply_M2               float64
# Inflation_Rate_Mom            float64
# Private_Sector_Credit         float64
# Consumer_Price_Index_CPI      float64
# CPI_Transportation            float64
# Money_Supply_M1               float64
# Banks_Balance_Sheet           float64
# Dolartoday                    float64
# dtype: object

# %%
df
# Out:
#       Unnamed: 0  Stock_Market  Deposit_Interest_Rate  Interest_Rate  \
# 0     2007-01-01  5.300000e-02                  10.53          18.93
# 1     2007-01-02  5.300000e-02                  10.12          18.93
# 2     2007-01-03  5.360000e-02                  10.07          18.24
# 3     2007-01-04  5.560000e-02                  10.01          14.77
# 4     2007-01-05  5.940000e-02                  10.03          17.43
# ...          ...           ...                    ...            ...
# 5432  2021-11-15  5.973510e+09                  36.00          56.86
# 5433  2021-11-16  5.962450e+09                  36.00          56.86
# 5434  2021-11-17  5.968420e+09                  36.00          56.86
# 5435  2021-11-18  5.998970e+09                  36.00          56.86
# 5436  2021-11-19  6.043920e+09                  36.00          56.86
#
#       Money_Supply_M3  Central_Bank_Balance_Sheet  Crude_Oil_Production  \
# ...

# %%
df['Unnamed: 0'] = df['Unnamed: 0'].apply(pd.to_datetime)

# %%
from datetime import timedelta

# %%
params1 = {
    'df' : df.iloc[-1]['Unnamed: 0'],
    'num_days' : df.iloc[-1]['Unnamed: 0'] + timedelta(days=30)
}

# %%
from datetime import datetime
date_time_str = '2021-12-19 08:15:27.243860'
date_time_obj = datetime.strptime(date_time_str, '%Y-%m-%d %H:%M:%S.%f')

# %%
params1['df']
# Out:
# Timestamp('2021-11-19 00:00:00')

# %%
datetime(2021,11,19)
# Out:
# datetime.datetime(2021, 11, 19, 0, 0)

# %%
url = 'http://localhost:8000/predict'
url1 = 'http://127.0.0.1:8000/predict' 
params = {'num_days':30}
response = requests.get(url1, params=params).json()
print(response)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /var/folders/5v/jrtfsf456ts80g8z3xvl3yq80000gn/T/ipykernel_16913/1793580261.py in <module>
#       2 url1 = 'http://127.0.0.1:8000/predict'
#       3 params = {'num_days':30}
# ----> 4 response = requests.get(url1, params=params).json()
#       5 print(response)
#
# ~/.pyenv/versions/3.8.12/envs/venezuela_fx/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
# ...

# %%
df
# Out:
#       Unnamed: 0  Stock_Market  Deposit_Interest_Rate  Interest_Rate  \
# 0     2007-01-01  5.300000e-02                  10.53          18.93
# 1     2007-01-02  5.300000e-02                  10.12          18.93
# 2     2007-01-03  5.360000e-02                  10.07          18.24
# 3     2007-01-04  5.560000e-02                  10.01          14.77
# 4     2007-01-05  5.940000e-02                  10.03          17.43
# ...          ...           ...                    ...            ...
# 5432  2021-11-15  5.973510e+09                  36.00          56.86
# 5433  2021-11-16  5.962450e+09                  36.00          56.86
# 5434  2021-11-17  5.968420e+09                  36.00          56.86
# 5435  2021-11-18  5.998970e+09                  36.00          56.86
# 5436  2021-11-19  6.043920e+09                  36.00          56.86
#
#       Money_Supply_M3  Central_Bank_Balance_Sheet  Crude_Oil_Production  \
# ...
